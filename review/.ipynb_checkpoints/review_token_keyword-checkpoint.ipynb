# %%
import pandas as pd
import matplotlib.pyplot as plt
import urllib.request
from tqdm import tqdm
from gensim.models.word2vec import Word2Vec
from konlpy.tag import Okt
from collections import Counter
import numpy as np

# %%
tokens=pd.read_csv('token_review.csv',encoding='utf-8', index_col='Unnamed: 0')
tokens['token_doc']
# Out:
# 0       ['좋다', '재질', '하의', '찾기', '적당하다', '어렵다', '수선', ...
# 1           ['크다', '입다', '확실하다', '거치다', '광택', '사이', '따다']
# 2       ['추천', '추천', '최고', '최고', '지인', '자다', '사다', '좋다...
# 3                         ['고급', '지고', '고급', '지다', '스타일']
# 4       ['빠르다', '배송', '포장', '사용', '예전', '이만', '신발', '좋...
#                               ...
# 4536    ['핑크', '자다', '신고', '일반', '양말', '예쁘다', '가격', '사다']
# 4537         ['여름', '입다', '예쁘다', '선선', '생각', '두껍다', '덥다']
# 4538                    ['친구', '선물', '두껍다', '선물', '따뜻하다']
# 4539                    ['편하다', '강추', '강하다', '강하다', '기본']
# 4540               ['셔츠', '디테일', '입다', '좋다', '살짝', '레이어']
# Name: token_doc, Length: 4541, dtype: object

# %%
import ast
tokens['token_doc'] = tokens['token_doc'].apply(ast.literal_eval)
tokenized_reviews = tokens['token_doc'].tolist()
word2vec_model = Word2Vec(sentences=tokenized_reviews, window=5,workers=4)
words = list(word2vec_model.wv.index_to_key)
word_vectors = {word: word2vec_model.wv[word] for word in words}

# %%
words
# Out:
# ['좋다',
#  '예쁘다',
#  '입다',
#  '사이즈',
#  '구매',
#  '편하다',
#  '자다',
#  '사다',
#  '생각',
#  '배송',
#  '디자인',
#  '마음',
#  '맞다',
#  '색감',
#  '만족하다',
#  '가격',
#  '색상',
#  '재질',
#  '빠르다',
#  '얇다',
#  '여름',
#  '저렴하다',
#  '느낌',
#  '적당하다',
#  '크다',
#  '아주',
#  '무난',
#  '바지',
#  '다니다',
#  '귀엽다',
#  '제품',
#  '부드럽다',
#  '괜찮다',
#  '두께',
#  '살짝',
#  '시원하다',
#  '듭니',
#  '소재',
#  '포인트',
#  '자주',
#  '추천',
#  '가성비',
#  '기장',
#  '따뜻하다',
#  '가볍다',
#  '길이',
#  '작다',
#  '쓰다',
#  '두껍다',
#  '원단',
#  '깔끔하다',
#  '구입',
#  '컬러',
#  '선물',
#  '어울리다',
#  '사용',
#  '허리',
#  '아쉽다',
#  '만족스럽다',
#  '넉넉하다',
#  '감다',
#  '오버핏',
#  '착용',
#  '에도',
#  '만족',
#  '기다',
#  '싸다',
#  '블랙',
#  '짧다',
#  '신다',
#  '탄탄하다',
#  '휘뚜루',
#  '감사하다',
#  '색도',
#  '좋아하다',
#  '크게',
#  '원하다',
#  '게요',
#  '할인',
#  '상품',
#  '퀄리티',
#  '운동',
#  '디테일',
#  '사진',
#  '모자',
#  '최고',
#  '프린팅',
#  '실물',
#  '주문',
#  '대비',
#  '셔츠',
#  '딱이다',
#  '겨울',
#  '기본',
#  '코디',
#  '신발',
#  '사고',
#  '포장',
#  '후기',
#  '편이',
#  '스타일',
#  '가을',
#  '오래',
#  '고민',
#  '수납',
#  '들어서다',
#  '드네',
#  '일리',
#  '처음',
#  '많다',
#  '별로',
#  '니트',
#  '덥다',
#  '커서',
#  '로고',
#  '색깔',
#  '넓다',
#  '살다',
#  '와이드',
#  '들어가다',
#  '밝다',
#  '양말',
#  '요즘',
#  '오버',
#  '신고',
#  '크기',
#  '티셔츠',
#  '드리다',
#  '불편하다',
#  '촉감',
#  '필요하다',
#  '화이트',
#  '화면',
#  '떨어지다',
#  '팬츠',
#  '세탁',
#  '항상',
#  '평소',
#  '빼다',
#  '흰색',
#  '전체',
#  '튼튼하다',
#  '찾다',
#  '브랜드',
#  '사서',
#  '후드',
#  '어깨',
#  '믿다',
#  '심플',
#  '사보다',
#  '여유',
#  '예쁘네',
#  '빨리',
#  '신기',
#  '쓸다',
#  '핑크',
#  '다드',
#  '무탠',
#  '가방',
#  '확실하다',
#  '주기',
#  '그레이',
#  '마감',
#  '부담',
#  '입어보다',
#  '편안하다',
#  '레이어',
#  '쓰기',
#  '합리',
#  '크롭',
#  '길다',
#  '빈티',
#  '넣다',
#  '늘어나다',
#  '물다',
#  '신축',
#  '활용',
#  '비다',
#  '품질',
#  '빠지다',
#  '해주다',
#  '지다',
#  '이라서',
#  '쿠폰',
#  '유니크',
#  '꼼꼼하다',
#  '비싸다',
#  '머리',
#  '따다',
#  '고급스럽다',
#  '무게',
#  '무겁다',
#  '네이비',
#  '공간',
#  '친구',
#  '갈다',
#  '완성도',
#  '서다',
#  '굉장하다',
#  '날씨',
#  '여기저기',
#  '가능하다',
#  '보이',
#  '소매',
#  '추가',
#  '베이지',
#  '질도',
#  '아이보리',
#  '아무',
#  '짱짱하다',
#  '애용',
#  '라인',
#  '굿굿',
#  '비치다',
#  '하니',
#  '워싱',
#  '여자친구',
#  '사주다',
#  '일해',
#  '나쁘다',
#  '촉촉하다',
#  '그대로',
#  '매치',
#  '고급',
#  '힘들다',
#  '발림',
#  '피부',
#  '매력',
#  '데님',
#  '붙다',
#  '크림',
#  '독특하다',
#  '해보다',
#  '사람',
#  '보온',
#  '걱정',
#  '벨트',
#  '교환',
#  '기준',
#  '발볼',
#  '순하다',
#  '일반',
#  '케이스',
#  '냄새',
#  '만들다',
#  '특이하다',
#  '벼워',
#  '지퍼',
#  '기분',
#  '아우',
#  '신어',
#  '번째',
#  '선명하다',
#  '나름',
#  '성비',
#  '세미',
#  '보통',
#  '다운',
#  '해봤다',
#  '두툼',
#  '깔다',
#  '스트링',
#  '되게',
#  '청바지',
#  '잡다',
#  '효과',
#  '패턴',
#  '높다',
#  '애매하다',
#  '추다',
#  '루즈',
#  '나서다',
#  '세트',
#  '아이템',
#  '어두운',
#  '느껴지다',
#  '입히다',
#  '바르다',
#  '간절',
#  '널널',
#  '매일',
#  '보리',
#  '파다',
#  '남자',
#  '구요',
#  '기대',
#  '도톰하다',
#  '맨투맨',
#  '질감',
#  '말다',
#  '스럽지',
#  '블프',
#  '으로도',
#  '미치다',
#  '자켓',
#  '핏감',
#  '상태',
#  '똑같다',
#  '품절',
#  '좁다',
#  '보내다',
#  '기간',
#  '부들부들하다',
#  '늘다',
#  '끼다',
#  '쫀쫀',
#  '희다',
#  '마르다',
#  '주머니',
#  '생기다',
#  '은은하다',
#  '어렵다',
#  '차콜',
#  '카라',
#  '기다리다',
#  '타이',
#  '밴딩',
#  '진하다',
#  '집업',
#  '려고',
#  '맞추다',
#  '브라운',
#  '잡히다',
#  '무신',
#  '상당하다',
#  '미니',
#  '다르다',
#  '착하다',
#  '슬랙스',
#  '걸치다',
#  '모양',
#  '팔이',
#  '버리다',
#  '계절',
#  '묻다',
#  '단독',
#  '밑단',
#  '짱짱',
#  '멀다',
#  '편입',
#  '니까',
#  '자수',
#  '벌써',
#  '맛집',
#  '건데',
#  '펴다',
#  '필요',
#  '무탠다드',
#  '반품',
#  '쉬다',
#  '얼굴',
#  '수도',
#  '용도',
#  '블루',
#  '의사',
#  '라지',
#  '기도',
#  '다양하다',
#  '선택',
#  '어둡다',
#  '스탠다드',
#  '울리다',
#  '회색',
#  '변형',
#  '핏이',
#  '느리다',
#  '다리',
#  '모델',
#  '조절',
#  '검정',
#  '일도',
#  '프린트',
#  '문제',
#  '용량',
#  '접다',
#  '걸리다',
#  '실제',
#  '느끼다',
#  '수선하다',
#  '상의',
#  '뭔가',
#  '뜨다',
#  '아들',
#  '강하다',
#  '튀다',
#  '이용',
#  '엄마',
#  '충분하다',
#  '무거워',
#  '품다',
#  '잠옷',
#  '기모',
#  '필수',
#  '구성',
#  '박스',
#  '자연스럽다',
#  '늦다',
#  '패딩',
#  '레터링',
#  '카드',
#  '두루',
#  '흡수',
#  '나가다',
#  '아프다',
#  '훌륭하다',
#  '셋업',
#  '돌리다',
#  '구김',
#  '힘드다',
#  '매다',
#  '주름',
#  '무드',
#  '기능',
#  '흔하다',
#  '깊다',
#  '지속',
#  '운동화',
#  '득템',
#  '부들부들',
#  '이며',
#  '투웨이',
#  '밴드',
#  '무조건',
#  '그래픽',
#  '와이프',
#  '분들',
#  '치수',
#  '여행',
#  '바스락',
#  '밉다',
#  '코트',
#  '실용',
#  '약하다',
#  '거리',
#  '평범하다',
#  '아디다스',
#  '옷감',
#  '기존',
#  '마뚜루',
#  '놓다',
#  '시즌',
#  '두툼해',
#  '라이트',
#  '동생',
#  '허다',
#  '만에',
#  '하루',
#  '놀다',
#  '핑크색',
#  '자극',
#  '쿠션',
#  '버전',
#  '매장',
#  '넥라인',
#  '바람',
#  '쿠어',
#  '유명하다',
#  '속옷',
#  '버뮤다',
#  '지도',
#  '참고',
#  '꾸다',
#  '물건',
#  '가죽',
#  '레드',
#  '초록색',
#  '그린',
#  '입구',
#  '깡패',
#  '보이지',
#  '찰떡',
#  '딱딱하다',
#  '지인',
#  '다행',
#  '잘살다',
#  '붙이다',
#  '틀다',
#  '어머니',
#  '야무지다',
#  '바닥',
#  '체험',
#  '허벅지',
#  '흘러내리다',
#  '벗기다',
#  '실밥',
#  '화사하다',
#  '드용',
#  '줄다',
#  '뻣뻣하다',
#  '검정색',
#  '힙하',
#  '올리다',
#  '보기',
#  '처리',
#  '톡톡하다',
#  '먼지',
#  '갖다',
#  '강추',
#  '손목',
#  '커버',
#  '적다',
#  '한여름',
#  '달라',
#  '라이브',
#  '그리다',
#  '스펙',
#  '단추',
#  '깊이',
#  '동일하다',
#  '차이',
#  '장난',
#  '발목',
#  '볼캡',
#  '오묘하다',
#  '거치다',
#  '발색',
#  '작년',
#  '줍다',
#  '미리',
#  '사이',
#  '남편',
#  '리스',
#  '이만',
#  '워낙',
#  '발도',
#  '예전',
#  '엉덩이',
#  '찍다',
#  '단점',
#  '치마',
#  '풀리다',
#  '예정',
#  '쫀쫀하',
#  '총장',
#  '금방',
#  '목걸이',
#  '입문',
#  '가슴',
#  '줄이다',
#  '신랑',
#  '치다',
#  '완벽하다',
#  '발라',
#  '체형',
#  '활동',
#  '먹다',
#  '다가',
#  '안경',
#  '중이',
#  '비교',
#  '이유',
#  '보들보들하다',
#  '일가',
#  '광택',
#  '샴푸',
#  '실내',
#  '쪼이다',
#  '피그먼트',
#  '메다',
#  '따갑다',
#  '심하다',
#  '수가',
#  '남아',
#  '골프',
#  '전반',
#  '한겨울',
#  '말리다',
#  '여자',
#  '한텐',
#  '추워지다',
#  '그것',
#  '삿어',
#  '예쁜데',
#  '새롭다',
#  '로이',
#  '먹이다',
#  '보풀',
#  '구기다',
#  '패키징',
#  '쉐입',
#  '쏘다',
#  '향수',
#  '그거',
#  '상세',
#  '가디건',
#  '부담스럽다',
#  '업다',
#  '은근',
#  '반바지',
#  '요새',
#  '스티치',
#  '칭찬',
#  '쌀쌀하다',
#  '덕분',
#  '좋아지다',
#  '먼저',
#  '막상',
#  '포켓',
#  '커플',
#  '중간',
#  '근본',
#  '검은색',
#  '마침',
#  '행사',
#  '아빠',
#  '바람막이',
#  '폴로',
#  '설명',
#  '은색',
#  '생일',
#  '도착',
#  '인기',
#  '구멍',
#  '남자친구',
#  '건지다',
#  '안감',
#  '비도',
#  '나일론',
#  '스타일링',
#  '미디엄',
#  '해도',
#  '클래식',
#  '캐릭터',
#  '정핏',
#  '장만',
#  '데일리',
#  '실버',
#  '베이직',
#  '꾸준하다',
#  '정력',
#  '사이드',
#  '돌다',
#  '바라다',
#  '세련되다',
#  '급하다',
#  '톰해',
#  '주얼',
#  '미스',
#  '린넨',
#  '상큼',
#  '박다',
#  '오렌지',
#  '에스',
#  '점퍼',
#  '레깅스',
#  '루즈핏',
#  '내기',
#  '둘레',
#  '연출',
#  '통풍',
#  '골반',
#  '리본',
#  '트이다',
#  '패드',
#  '예쁩니다',
#  '나인',
#  '유행',
#  '벙벙하다',
#  '거려',
#  '너무나',
#  '라면',
#  '하늘색',
#  '적당',
#  '나머지',
#  '무늬',
#  '무지',
#  '모공',
#  '대신',
#  '비니',
#  '건조기',
#  '조이다',
#  '파란색',
#  '기대하다',
#  '스몰',
#  '기네',
#  '이기다',
#  '그치다',
#  '핏되',
#  '트렌디',
#  '보드랍다',
#  '소리',
#  '스럽게',
#  '무릎',
#  '물놀이',
#  '알맞다',
#  '살리다',
#  '가깝다',
#  '슬리브',
#  '입지',
#  '낮다',
#  '강력',
#  '단정하다',
#  '에서도',
#  '편리하다',
#  '리하',
#  '렌즈',
#  '로는',
#  '요가',
#  '반지',
#  '사실',
#  '아래',
#  '면도',
#  '외출',
#  '유용하다',
#  '클렌징',
#  '퍼지다',
#  '로우',
#  '올라오다',
#  '낙하',
#  '발리',
#  '유지',
#  '하의',
#  '번창',
#  '여성',
#  '적립금',
#  '키링',
#  '신경',
#  '힙해',
#  '나요',
#  '찌다',
#  '타입',
#  '수선',
#  '등산',
#  '얼른',
#  '푹신하다',
#  '요핏',
#  '배색',
#  '뷰티',
#  '예약',
#  '스트릿',
#  '멋지다',
#  '뛰어나다',
#  '찾기',
#  '바디',
#  '반스',
#  '밋밋하다',
#  '부츠',
#  '더워지다',
#  '코듀',
#  '솔직하다',
#  '살이',
#  '맨날',
#  '여유롭다',
#  '맛있다',
#  '슬림',
#  '가운데',
#  '올리브',
#  '끌리다',
#  '수영복',
#  '상관없다',
#  '사도',
#  '엑스',
#  '개시',
#  '드디어',
#  '사면',
#  '출근',
#  '범용',
#  '메기',
#  '전투',
#  '다행하다',
#  '지지',
#  '오빠',
#  '밀리터리',
#  '구두',
#  '소화',
#  '네오',
#  '슬리퍼',
#  '조합',
#  '이면',
#  '뽑다',
#  '가면',
#  '학년',
#  '오래오래',
#  '달라붙다',
#  '반하다',
#  '가리다',
#  '뚜껑',
#  '후회',
#  '선호',
#  '레더',
#  '자동',
#  '아기',
#  '뿌리다',
#  '여름철',
#  '구여',
#  '헤비',
#  '풀다',
#  '건조',
#  '쨍해',
#  '오트밀',
#  '파이다',
#  '카키',
#  '변형도',
#  '줄어들다',
#  '패치',
#  '빨다',
#  '거품',
#  '최근',
#  '베이지색',
#  '수고',
#  '메쉬',
#  '고르다',
#  '제법',
#  '러닝',
#  '베스트',
#  '포근하다',
#  '산책',
#  '초가을',
#  '수준',
#  '일로',
#  '이구',
#  '웨어',
#  '트레이닝',
#  '이지',
#  '흐물거리',
#  '딱하다',
#  '특유',
#  '바꾸다',
#  '다크',
#  '체크',
#  '결혼식',
#  '지갑',
#  '원피스',
#  '지나다',
#  '당황',
#  '디네',
#  '초여름',
#  '다리다',
#  '더욱',
#  '표현',
#  '레이저',
#  '시티',
#  '가기',
#  '묵직하다',
#  '부족하다',
#  '개다',
#  '회사',
#  '수분',
#  '웜톤',
#  '무료',
#  '동네',
#  '저녁',
#  '랑은',
#  '원대',
#  '음질',
#  '햇빛',
#  '스트라이프',
#  '들어오다',
#  '노랗다',
#  '매트',
#  '아웃']

# %%
len(words)
# Out:
# 851

# %%
reviews=pd.read_csv('review_40000_data.csv', encoding='utf-8')
reviews.head()
# Out:
#   user_id  level          user_info                           hash_id  \
# 0  치킨무222      8                NaN  efa39b750c5e9e4fbe8103138b7356be
# 1  치킨무222      8  남성 · 170cm · 70kg  efa39b750c5e9e4fbe8103138b7356be
# 2  치킨무222      8                NaN  efa39b750c5e9e4fbe8103138b7356be
# 3  치킨무222      8                NaN  efa39b750c5e9e4fbe8103138b7356be
# 4  치킨무222      8  남성 · 170cm · 70kg  efa39b750c5e9e4fbe8103138b7356be
#
#   review_date  product_id product_brand  \
# 0  2022-06-06   1738747.0            휠라
# 1  2022-06-06   1971242.0          아디다스
# 2  2022-06-06   2359791.0       락피쉬웨더웨어
# 3  2022-06-06   2394774.0       락피쉬웨더웨어
# 4  2022-06-06   2431241.0         마하그리드
#
#                              product_name product_option  \
# 0         FORCE BLACK 샤코슈(FS3BCD5326XBLK)      BLACK/000
# 1                    에센셜 티 - 화이트 / GN3415              S
# 2                       벨라 메리제인 체크 - NAVY       NAVY/250
# 3                        위즐리 메리제인 - BLACK      BLACK/230
# 4  THRILLER MAN TEE CHARCOAL(MG2CMMT511A)           차콜/L
#
#                                     review_text  star_rating  helpful_count  \
# 0  모든 옷에 편하게 잘 입을 수 있을 것 같습니다. 가성비 좋네요 ! 추천합니다!            5              0
# 1  모든 옷에 편하게 잘 입을 수 있을 것 같습니다. 가성비 좋네요 ! 추천합니다!            5              0
# 2  모든 옷에 편하게 잘 입을 수 있을 것 같습니다. 가성비 좋네요 ! 추천합니다!            5              0
# 3  모든 옷에 편하게 잘 입을 수 있을 것 같습니다. 가성비 좋네요 ! 추천합니다!            5              0
# 4  모든 옷에 편하게 잘 입을 수 있을 것 같습니다. 가성비 좋네요 ! 추천합니다!            5              0
#
#      사이즈     밝기     색감    두께감  count
# 0  보통이에요  보통이에요  보통이에요    NaN   2444
# 1  보통이에요  보통이에요  보통이에요  보통이에요   2444
# 2  보통이에요  보통이에요  보통이에요    NaN   2444
# 3  보통이에요  보통이에요  보통이에요    NaN   2444
# 4  보통이에요  보통이에요  보통이에요  보통이에요   2444

# %%
combined_reviews = reviews.groupby('user_id')['review_text'].apply(lambda x: ' '.join(set(x))).reset_index()
combined_reviews.head()
# Out:
#    user_id                                        review_text
# 0   !!??!?  90일된 아기한테 적당히 잘맞아요ㅎㅎ 딱이쁘게입힐사이즈입니다. 신축성이 다소 아쉽습...
# 1  !!ㅇㅈㅁ!!  진짜 두꺼워서 엄청 따듯해요. 근데 털이 빠지는게 안에 검정옷 입으면 큰일 날 듯 ...
# 2    !i!i!  포인트 얹기가 너무 좋아서 자주 손이 가요! 색도 실제로 보니 더 예쁘네요 색감 미...
# 3    !•c•!  향이 좀 달아요! 상쾌하고 상큼하고 단 향… 밝은 색 옷에 잘 어울릴 것 같아요. ...
# 4    !ㅇㅁㅇ!  시원하고 얇아서 좋아요, 여타 프리미엄진에 비해 딱히 부족한점 없어 보여요 배송 빠...

# %%
combined_reviews['review_text']=combined_reviews['review_text'].str.replace("[^ㄱ-하-ㅣ가-힣 ]","")
combined_reviews['review_text'].dropna(inplace=True)
# Out:
# C:\Users\duwjd\AppData\Local\Temp\ipykernel_9276\2745201745.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   combined_reviews['review_text']=combined_reviews['review_text'].str.replace("[^ㄱ-하-ㅣ가-힣 ]","")

# %%
from hanspell import spell_checker

spell=[]
for i in tqdm(range(len(combined_reviews['review_text']))):
    try:
        sent = combined_reviews.iloc[i,1]
        spelled_sent = spell_checker.check(sent)
        hanspell_sent = spelled_sent.checked
        spell.append(hanspell_sent)
    except:
        spell.append("")

combined_reviews['spell_doc']=spell
combined_reviews
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 38396/38396 [02:04<00:00, 309.14it/s]
#        user_id                                        review_text spell_doc
# 0       !!??!?  배송도 빠르고 저렴하게 구매했어요 키로 개월 남아에게도 잘어울리네요 아기기 잘머거서...
# 1      !!ㅇㅈㅁ!!  옷이 부드럽고 두꺼워서 잘 입고 있어요 그리고 편해서 좋네요 너무 잘 입고 있습니다...
# 2        !i!i!  발수도 잘 되고 양산으로서의 기능도 확실해요 무엇보다도 접고 펼 때 부드럽게 움직여...
# 3        !•c•!  보풀이 짱 심합니다 입고 나간 날은 항상 제거해주고 있어요 귀찮긴 한데 이뻐서 ㄱㅊ...
# 4        !ㅇㅁㅇ!  색감이 너무 좋고 재질도 만족합니다 추천합니다 배송 빠르고 만족합니다 틴트라서 투과...
# ...        ...                                                ...       ...
# 38391     힣헿훟힣  바를 때 조금 따가워요전 피부장벽개선후 발라야 효과가있을고같아요 굉장히 이쁩니다 원...
# 38392    劉 周 城  옷이 예쁘고 잘맞아요 잘입겠습니다 느아으아앙앙아 깡 형님 믿고 구입 완전 도톰하고 ...
# 38393        柳  평소 신는데 이것도 하니 잘 맞습니다 혜자스러운 금액 감사합니다 한 해는 끄떡 없겠...
# 38394       ｡｡  공병을 못구해서 아직 못써봤지만 즐겨보는 유튜버가 쓰는 제품이라 기대가 됩니다 가볍...
# 38395      ･ᴗ･  생각보다 부들거려요 아직까지는 따가운 것도 없는 것 같아요 디자인도 예쁘고 좋네요 ...
#
# [38396 rows x 3 columns]

# %%
combined_reviews['spell_doc'].replace('', pd.NA, inplace=True)
combined_reviews['combined'] = combined_reviews['spell_doc'].fillna(combined_reviews['review_text'])
combined_reviews
# Out:
#        user_id                                        review_text spell_doc  \
# 0       !!??!?  배송도 빠르고 저렴하게 구매했어요 키로 개월 남아에게도 잘어울리네요 아기기 잘머거서...       NaN
# 1      !!ㅇㅈㅁ!!  옷이 부드럽고 두꺼워서 잘 입고 있어요 그리고 편해서 좋네요 너무 잘 입고 있습니다...       NaN
# 2        !i!i!  발수도 잘 되고 양산으로서의 기능도 확실해요 무엇보다도 접고 펼 때 부드럽게 움직여...       NaN
# 3        !•c•!  보풀이 짱 심합니다 입고 나간 날은 항상 제거해주고 있어요 귀찮긴 한데 이뻐서 ㄱㅊ...       NaN
# 4        !ㅇㅁㅇ!  색감이 너무 좋고 재질도 만족합니다 추천합니다 배송 빠르고 만족합니다 틴트라서 투과...       NaN
# ...        ...                                                ...       ...
# 38391     힣헿훟힣  바를 때 조금 따가워요전 피부장벽개선후 발라야 효과가있을고같아요 굉장히 이쁩니다 원...       NaN
# 38392    劉 周 城  옷이 예쁘고 잘맞아요 잘입겠습니다 느아으아앙앙아 깡 형님 믿고 구입 완전 도톰하고 ...       NaN
# 38393        柳  평소 신는데 이것도 하니 잘 맞습니다 혜자스러운 금액 감사합니다 한 해는 끄떡 없겠...       NaN
# 38394       ｡｡  공병을 못구해서 아직 못써봤지만 즐겨보는 유튜버가 쓰는 제품이라 기대가 됩니다 가볍...       NaN
# 38395      ･ᴗ･  생각보다 부들거려요 아직까지는 따가운 것도 없는 것 같아요 디자인도 예쁘고 좋네요 ...       NaN
#
#                                                 combined
# 0      배송도 빠르고 저렴하게 구매했어요 키로 개월 남아에게도 잘어울리네요 아기기 잘머거서...
# 1      옷이 부드럽고 두꺼워서 잘 입고 있어요 그리고 편해서 좋네요 너무 잘 입고 있습니다...
# 2      발수도 잘 되고 양산으로서의 기능도 확실해요 무엇보다도 접고 펼 때 부드럽게 움직여...
# 3      보풀이 짱 심합니다 입고 나간 날은 항상 제거해주고 있어요 귀찮긴 한데 이뻐서 ㄱㅊ...
# 4      색감이 너무 좋고 재질도 만족합니다 추천합니다 배송 빠르고 만족합니다 틴트라서 투과...
# ...                                                  ...
# 38391  바를 때 조금 따가워요전 피부장벽개선후 발라야 효과가있을고같아요 굉장히 이쁩니다 원...
# 38392  옷이 예쁘고 잘맞아요 잘입겠습니다 느아으아앙앙아 깡 형님 믿고 구입 완전 도톰하고 ...
# 38393  평소 신는데 이것도 하니 잘 맞습니다 혜자스러운 금액 감사합니다 한 해는 끄떡 없겠...
# 38394  공병을 못구해서 아직 못써봤지만 즐겨보는 유튜버가 쓰는 제품이라 기대가 됩니다 가볍...
# 38395  생각보다 부들거려요 아직까지는 따가운 것도 없는 것 같아요 디자인도 예쁘고 좋네요 ...
#
# [38396 rows x 4 columns]

# %%
combined_reviews.drop('spell_doc', axis=1,inplace=True)

# %%
# 불용어 정의
with open('stopwords.txt', 'r') as f:
    list_file = f.readlines()
stopwords = list_file[0].split(",")

okt = Okt()

tokenized_data = []
for sentence in tqdm(combined_reviews['combined']):
    tokenized_sentence = okt.morphs(sentence, stem=True)  # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords and len(word) >= 2]  # 불용어 제거
    tokenized_data.append(stopwords_removed_sentence)

token_counter = Counter(token for sentence in tokenized_data for token in sentence)

filtered_tokenized_data = []
for sentence in tokenized_data:
    filtered_sentence = [word for word in sentence if token_counter[word] > 3]
    filtered_tokenized_data.append(filtered_sentence)

combined_reviews['token_doc'] = filtered_tokenized_data
combined_reviews
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 38396/38396 [4:49:37<00:00,  2.21it/s]
#        user_id                                        review_text  \
# 0       !!??!?  배송도 빠르고 저렴하게 구매했어요 키로 개월 남아에게도 잘어울리네요 아기기 잘머거서...
# 1      !!ㅇㅈㅁ!!  옷이 부드럽고 두꺼워서 잘 입고 있어요 그리고 편해서 좋네요 너무 잘 입고 있습니다...
# 2        !i!i!  발수도 잘 되고 양산으로서의 기능도 확실해요 무엇보다도 접고 펼 때 부드럽게 움직여...
# 3        !•c•!  보풀이 짱 심합니다 입고 나간 날은 항상 제거해주고 있어요 귀찮긴 한데 이뻐서 ㄱㅊ...
# 4        !ㅇㅁㅇ!  색감이 너무 좋고 재질도 만족합니다 추천합니다 배송 빠르고 만족합니다 틴트라서 투과...
# ...        ...                                                ...
# 38391     힣헿훟힣  바를 때 조금 따가워요전 피부장벽개선후 발라야 효과가있을고같아요 굉장히 이쁩니다 원...
# 38392    劉 周 城  옷이 예쁘고 잘맞아요 잘입겠습니다 느아으아앙앙아 깡 형님 믿고 구입 완전 도톰하고 ...
# 38393        柳  평소 신는데 이것도 하니 잘 맞습니다 혜자스러운 금액 감사합니다 한 해는 끄떡 없겠...
# 38394       ｡｡  공병을 못구해서 아직 못써봤지만 즐겨보는 유튜버가 쓰는 제품이라 기대가 됩니다 가볍...
# 38395      ･ᴗ･  생각보다 부들거려요 아직까지는 따가운 것도 없는 것 같아요 디자인도 예쁘고 좋네요 ...
#
#                                                 combined  \
# 0      배송도 빠르고 저렴하게 구매했어요 키로 개월 남아에게도 잘어울리네요 아기기 잘머거서...
# 1      옷이 부드럽고 두꺼워서 잘 입고 있어요 그리고 편해서 좋네요 너무 잘 입고 있습니다...
# 2      발수도 잘 되고 양산으로서의 기능도 확실해요 무엇보다도 접고 펼 때 부드럽게 움직여...
# 3      보풀이 짱 심합니다 입고 나간 날은 항상 제거해주고 있어요 귀찮긴 한데 이뻐서 ㄱㅊ...
# 4      색감이 너무 좋고 재질도 만족합니다 추천합니다 배송 빠르고 만족합니다 틴트라서 투과...
# ...                                                  ...
# 38391  바를 때 조금 따가워요전 피부장벽개선후 발라야 효과가있을고같아요 굉장히 이쁩니다 원...
# 38392  옷이 예쁘고 잘맞아요 잘입겠습니다 느아으아앙앙아 깡 형님 믿고 구입 완전 도톰하고 ...
# 38393  평소 신는데 이것도 하니 잘 맞습니다 혜자스러운 금액 감사합니다 한 해는 끄떡 없겠...
# 38394  공병을 못구해서 아직 못써봤지만 즐겨보는 유튜버가 쓰는 제품이라 기대가 됩니다 가볍...
# 38395  생각보다 부들거려요 아직까지는 따가운 것도 없는 것 같아요 디자인도 예쁘고 좋네요 ...
#
#                                                token_doc
# 0      [배송, 빠르다, 저렴하다, 구매, 키로, 개월, 남아, 에게도, 어울리다, 아기,...
# 1      [부드럽다, 두껍다, 자다, 입다, 편하다, 좋다, 자다, 입다, 허리, 크다, 빨...
# 2      [수도, 자다, 양산, 으로서의, 기능, 확실하다, 보다도, 접다, 펴다, 부드럽다...
# 3      [보풀, 심하다, 입다, 나가다, 항상, 제거, 해주다, 귀찮다, 이쁘다, ㄱㅊㄱㅊ...
# 4      [색감, 좋다, 재질, 만족하다, 추천, 배송, 빠르다, 만족하다, 틴트, 좋다, ...
# ...                                                  ...
# 38391  [바르다, 따갑다, 요전, 피부, 장벽, 선후, 발라, 효과, 굉장하다, 이쁘다, ...
# 38392  [예쁘다, 잘맞다, 입다, 으아, 형님, 믿다, 구입, 도톰하다, 좋다, 날씨, 구...
# 38393  [평소, 신다, 하니, 자다, 맞다, 혜자, 스러운, 금액, 감사하다, 여름, 입다...
# 38394  [공병, 구해, 즐기다, 유튜버, 쓰다, 제품, 기대, 가볍다, 바르다, 좋다, 두...
# 38395  [생각, 부들, 거려, 까지는, 따갑다, 디자인, 예쁘다, 좋다, 평소, 다니다, ...
#
# [38396 rows x 4 columns]

# %%
df1=pd.read_csv('review_token_40000.csv',encoding='utf-8',index_col='Unnamed: 0')
df1
# Out:
#        user_id                                          token_doc
# 0       !!??!?  ['배송', '빠르다', '저렴하다', '구매', '키로', '개월', '남아', ...
# 1      !!ㅇㅈㅁ!!  ['부드럽다', '두껍다', '입다', '편하다', '좋다', '입다', '허리',...
# 2        !i!i!  ['수도', '양산', '으로서의', '기능', '확실하다', '보다도', '접다'...
# 3        !•c•!  ['보풀', '심하다', '입다', '나가다', '항상', '제거', '해주다', ...
# 4        !ㅇㅁㅇ!  ['색감', '좋다', '재질', '만족하다', '추천', '배송', '빠르다', ...
# ...        ...                                                ...
# 38391     힣헿훟힣  ['바르다', '따갑다', '요전', '피부', '장벽', '선후', '발라', '...
# 38392    劉 周 城  ['예쁘다', '잘맞다', '입다', '으아', '형님', '믿다', '구입', '...
# 38393        柳  ['평소', '신다', '하니', '맞다', '혜자', '스러운', '금액', '감...
# 38394       ｡｡  ['공병', '구해', '즐기다', '유튜버', '제품', '기대', '가볍다', ...
# 38395      ･ᴗ･  ['생각', '부들', '거려', '까지는', '따갑다', '디자인', '예쁘다',...
#
# [38396 rows x 2 columns]

# %%
replacements = {
    '버핏' : '오버핏',
    '빨르다' : '빠르다',
    '디테' : '디테일',
    '이쁘다' : '예쁘다',
    '쁘네' : '예쁘네',
    '휘뚜루' : '휘뚜루',
    '뚜루' : '휘뚜루',
    '휘뚤마뚤' : '휘뚜루',
    '성도' : '완성도',
    '두운' : '어두운',
    '투맨' : '맨투맨',
    '조아' : '좋다',
    '레터' : '레터링',
    '웨이' : '투웨이',
    '데일' : '데일리',
    '쁜데' : '예쁜데',
    '쁩니' : '예쁩니다',
    '핏입니' : '핏입니다',
    '가성' : '가성비',
    '기대하다' : '기대',
    '두툼해' : '두껍다',
    '도톰하다' : '두껍다',
    '만족스럽다' : '만족',
    '만족하다': '만족',
    '맨날' : '매일',
    '무신' : '무신사',
    '무탠' : '무탠다드',
    '보리' : '시보리',
    '비다' : '빠지다',
    '사고' : '사다',
    '사면': '사다',
    '사보다': '사다',
    '사서': '사다',
    '사주다': '사다',
    '사이' : '사이즈',
    '색감' : '색상',
    '색도' : '색상',
    '색깔' : '색상',
    '신고':'신다',
    '신기':'신다',
    '요새' : '요즘',
    '입어보다':'입다',
    '전반' : '전체',
    '좋아하다' : '좋다',
    '커서':'크다',
    '편안하다':'편하다',
    '편이':'편하다',
    '프린트':'프린팅',
    '필요하다':'필수'
}

delete_words = {
    '자다', '쓰다','갈다','감다','개다','거품','그것','기다','깔다','꾸다','나가다','나인','너무나','넣다','늘다','다드','돌다','돌리다','듭니','따다',
    '리하','마뚜루','만에','물다','바르다','뿌리다','스럽게','쏘다','쓸다','쓰기','아무','아래','아주','에도','에어도','에스','웨어','으로도','이라서',
    '이만','이며','이지','일가','일리','일해','자수','잘살다','잡다','질도','찌다','추다','쿠어','편입','해보다','해봤다','해주다',
}

def replace_and_delete_tokens(tokens, replacements, delete_words):
    return [replacements.get(token, token) for token in tokens if token not in delete_words]

# Apply function to 'token_doc' column
combined_reviews['token_doc'] = combined_reviews['token_doc'].apply(lambda x: replace_and_delete_tokens(x, replacements, delete_words))
combined_reviews
# Out:
#        user_id token_doc
# 0       !!??!?        []
# 1      !!ㅇㅈㅁ!!        []
# 2        !i!i!        []
# 3        !•c•!        []
# 4        !ㅇㅁㅇ!        []
# ...        ...       ...
# 38391     힣헿훟힣        []
# 38392    劉 周 城        []
# 38393        柳        []
# 38394       ｡｡        []
# 38395      ･ᴗ･        []
#
# [38396 rows x 2 columns]

# %%
df1['token_doc'] = df1['token_doc'].apply(lambda x: eval(x) if isinstance(x, str) else x)

def filter_tokens(tokens, model):
    return [token for token in tokens if token in model.wv]

filtered_reviews = [filter_tokens(review, word2vec_model) for review in df1['token_doc']]

def get_keywords_by_frequency(tokens, top_n=5):
    frequency = Counter(tokens)
    return [keyword for keyword, _ in frequency.most_common(top_n)]

def get_average_vector(tokens, model):
    vectors = [model.wv[token] for token in tokens if token in model.wv]
    return np.mean(vectors, axis=0) if vectors else np.zeros(model.vector_size)

def find_closest_words(vector, model, topn=5):
    return [word for word, _ in model.wv.similar_by_vector(vector, topn=topn)]

# Extract keywords for each review
keywords_by_frequency = [get_keywords_by_frequency(review) for review in filtered_reviews]
keywords_by_similarity = []

for review in tqdm(filtered_reviews):
    average_vector = get_average_vector(review, word2vec_model)
    similar_keywords = find_closest_words(average_vector, word2vec_model)
    keywords_by_similarity.append(similar_keywords)

# Convert keywords to string format for DataFrame
keywords_by_frequency_str = [' '.join(keywords) for keywords in keywords_by_frequency]
keywords_by_similarity_str = [' '.join(keywords) for keywords in keywords_by_similarity]

# Add new columns to the DataFrame
df1['keywords_by_frequency'] = keywords_by_frequency_str
df1['keywords_by_similarity'] = keywords_by_similarity_str
df1
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 38396/38396 [01:10<00:00, 547.19it/s]
#        user_id                                          token_doc  \
# 0       !!??!?  [배송, 빠르다, 저렴하다, 구매, 키로, 개월, 남아, 에게도, 어울리다, 아기,...
# 1      !!ㅇㅈㅁ!!  [부드럽다, 두껍다, 입다, 편하다, 좋다, 입다, 허리, 크다, 빨래, 허리, 삼...
# 2        !i!i!  [수도, 양산, 으로서의, 기능, 확실하다, 보다도, 접다, 펴다, 부드럽다, 움직...
# 3        !•c•!  [보풀, 심하다, 입다, 나가다, 항상, 제거, 해주다, 귀찮다, 예쁘다, ㄱㅊㄱㅊ...
# 4        !ㅇㅁㅇ!  [색감, 좋다, 재질, 만족하다, 추천, 배송, 빠르다, 만족하다, 틴트, 좋다, ...
# ...        ...                                                ...
# 38391     힣헿훟힣  [바르다, 따갑다, 요전, 피부, 장벽, 선후, 발라, 효과, 굉장하다, 예쁘다, ...
# 38392    劉 周 城  [예쁘다, 잘맞다, 입다, 으아, 형님, 믿다, 구입, 도톰하다, 좋다, 날씨, 구...
# 38393        柳  [평소, 신다, 하니, 맞다, 혜자, 스러운, 금액, 감사하다, 여름, 입다, 적합...
# 38394       ｡｡  [공병, 구해, 즐기다, 유튜버, 제품, 기대, 가볍다, 바르다, 좋다, 두껍다, ...
# 38395      ･ᴗ･  [생각, 부들, 거려, 까지는, 따갑다, 디자인, 예쁘다, 좋다, 평소, 다니다, ...
#
#       keywords_by_frequency keywords_by_similarity
# 0         구매 입히다 저렴하다 좋다 크다        사다 쓰다 코디 귀엽다 느낌
# 1          예쁘다 입다 좋다 크다 다니다        사다 예쁘다 좋다 코디 생각
# 2         좋다 입다 예쁘다 다니다 편하다         사다 코디 쓰다 좋다 생각
# 3          좋다 예쁘다 입다 선물 사이즈         사다 코디 느낌 생각 좋다
# 4         배송 빠르다 좋다 제품 만족하다     사다 좋다 만족스럽다 귀엽다 생각
# ...                     ...                    ...
# 38391      바르다 좋다 입다 두껍다 크다         사다 쓰다 코디 느낌 생각
# 38392       예쁘다 입다 좋다 구입 구매        사다 예쁘다 입다 좋다 코디
# 38393     좋다 만족하다 사이즈 입다 추천     사다 코디 만족스럽다 쓰다 귀엽다
# 38394      좋다 배송 사다 빠르다 예쁘다        사다 좋다 쓰다 귀엽다 코디
# 38395      좋다 예쁘다 사이즈 살짝 사다        사다 좋다 예쁘다 코디 생각
#
# [38396 rows x 4 columns]

# %%
save_review=df1.loc[:,['user_id','keywords_by_frequency','keywords_by_similarity']]
save_review.to_csv('review_keyword_40000.csv', encoding='utf-8')

# %%
# token_review=combined_reviews.loc[:,['user_id','token_doc']]
# token_review.to_csv('review_token_40000.csv', encoding='utf-8')
