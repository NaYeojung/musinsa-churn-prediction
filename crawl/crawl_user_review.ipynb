# %%
# 무신사 허락 user-agents
USER_AGENTS = [
    "Googlebot/2.1 (+http://www.google.com/bot.html)",
    "Mozilla/5.0 (compatible; Yeti/1.1; +http://naver.me/bot)",
    "Daumoa/5.0 (+http://partner.daum.net)",
    "Mozilla/5.0 (compatible; DaumWebCrawler; +http://partner.daum.net)",
    "Mozilla/5.0 (compatible; FacebookBot/1.0; +http://www.facebook.com/externalhit_uatext.php)",
    "facebookexternalhit/1.1 (+http://www.facebook.com/externalhit_uatext.php)"
]

# %%
import aiohttp
import asyncio
import random
from bs4 import BeautifulSoup
import csv
import nest_asyncio
from tqdm.asyncio import tqdm
import pandas as pd

nest_asyncio.apply()

# 입력 데이터 설정
years = [2023, 2024]
max_pages = float('inf')  # 페이지 수에 제한 없음



async def fetch(session, url, params, headers):
    async with session.get(url, params=params, headers=headers) as response:
        return await response.text()

async def get_total_review_count(session, year, hash_id):
    base_url = "https://www.musinsa.com/goods/reviews/lists"
    params = {
        'searchYear': year,
        'searchMonth': 0,
        'type': '',
        'page': 1,
        'shop_domain': 'https://www.musinsa.com',
        'hashId': hash_id
    }
    headers = {
        'User-Agent': random.choice(USER_AGENTS)
    }
    response_text = await fetch(session, base_url, params, headers)
    soup = BeautifulSoup(response_text, 'html.parser')
    count_element = soup.select_one("body > main > form > div.wrap-estimate-list > div.n-list-util > div.count > strong")
    
    if not count_element:
        print(f"No review count element found for {year}.")
        return 0
    
    count_text = count_element.text.strip().replace(',', '')
    
    try:
        total_count = int(count_text)
    except ValueError:
        print(f"Failed to convert review count to an integer for {year}.")
        return 0
    
    return total_count

async def get_reviews_page(session, year, hash_id, page):
    base_url = "https://www.musinsa.com/goods/reviews/lists"
    params = {
        'searchYear': year,
        'searchMonth': 0,
        'type': '',
        'page': page,
        'shop_domain': 'https://www.musinsa.com',
        'hashId': hash_id
    }
    headers = {
        'User-Agent': random.choice(USER_AGENTS)
    }
    response_text = await fetch(session, base_url, params, headers)
    soup = BeautifulSoup(response_text, 'html.parser')
    review_list = soup.select("#reviewContentWrap > div")

    reviews = []
    for review in review_list:
        # Parsing logic for each review
        user_id = review.select_one('div.review-profile > div > div.review-profile__text > p.review-profile__name').text.strip() if review.select_one('div.review-profile > div > div.review-profile__text > p.review-profile__name') else ''
        user_info = review.select_one('div.review-profile > div > div.review-profile__information.review-profile__information--brandshop > p > span').text.strip() if review.select_one('div.review-profile > div > div.review-profile__information.review-profile__information--brandshop > p > span') else ''
        review_date = review.select_one('p.review-profile__date').text.strip() if review.select_one('p.review-profile__date') else ''
        product_id = ''
        product_link = review.select_one('a.review-goods-information__name')['href'] if review.select_one('a.review-goods-information__name') else ''
        if product_link:
            product_id = product_link.split('/')[-2]
        product_brand = review.select_one('a.review-goods-information__brand').text.strip() if review.select_one('a.review-goods-information__brand') else ''
        product_name = review.select_one('a.review-goods-information__name').text.strip() if review.select_one('a.review-goods-information__name') else ''
        product_option = review.select_one('div.review-goods-information__item > p > span').text.strip() if review.select_one('div.review-goods-information__item > p > span') else ''

        review_text = review.select_one('div.review-contents__text').text.strip() if review.select_one('div.review-contents__text') else ''
        star_rating_elem = review.select_one('div.review-list__rating-wrap > span > span > span.review-list__rating__active')
        star_rating = int(star_rating_elem['style'].split(': ')[1].replace('%', '')) // 20 if star_rating_elem else 0

        evaluate_tags = {
            '사이즈': '',
            '밝기': '',
            '색감': '',
            '두께감': ''
        }
        evaluation_elements = review.select('div.review-contents > div.review-evaluation--type2 > ul > li')
        for elem in evaluation_elements:
            key = elem.text.split(' ')[0].strip()
            value = elem.select_one('span').text.strip() if elem.select_one('span') else ''
            if key in evaluate_tags:
                evaluate_tags[key] = value

        helpful_count = review.select_one('div.review-evaluation-button--type3 > ul > li:nth-child(1) > label > span').text.strip() if review.select_one('div.review-evaluation-button--type3 > ul > li:nth-child(1) > label > span') else ''
        nicestyle_count = review.select_one('div.review-evaluation-button--type3 > ul > li:nth-child(2) > label > span').text.strip() if review.select_one('div.review-evaluation-button--type3 > ul > li:nth-child(2) > label > span') else ''

        review_data = {
            'user_id': user_id,
            'user_info': user_info,
            'review_date': review_date,
            'product_id': product_id,
            'product_brand': product_brand,
            'product_name': product_name,
            'product_option': product_option,
            'review_text': review_text,
            'star_rating': star_rating,
            'helpful_count': helpful_count,
            'nicestyle_count': nicestyle_count,
            'hash_id': hash_id  # Add hash_id to each review
        }
        review_data.update(evaluate_tags)
        reviews.append(review_data)

    return reviews

async def get_reviews_year(session, year, hash_id, max_pages):
    total_count = await get_total_review_count(session, year, hash_id)
    pages_to_crawl = min((total_count // 20) + 1, max_pages)

    tasks = [get_reviews_page(session, year, hash_id, page) for page in range(1, pages_to_crawl + 1)]
    results = []

    for task in tqdm(asyncio.as_completed(tasks), total=pages_to_crawl, desc=f"{year} 크롤링 진행 상황"):
        result = await task
        results.append(result)

    reviews = [review for result in results for review in result]
    return reviews

def remove_duplicates(reviews):
    unique_reviews = []
    seen = set()

    for review in reviews:
        identifier = (review['review_date'], review['product_id'])

        if identifier not in seen:
            unique_reviews.append(review)
            seen.add(identifier)

    return unique_reviews

async def crawl_reviews_for_all_hash_ids(hash_ids, years, max_pages):
    async with aiohttp.ClientSession() as session:
        all_reviews = []

        for hash_id in hash_ids:
            for year in years:
                try:
                    reviews = await get_reviews_year(session, year, hash_id, max_pages)
                    all_reviews.extend(reviews)
                except Exception as e:
                    print(f"Error on {year} for hash_id {hash_id}: {e}")

        unique_reviews = remove_duplicates(all_reviews)
        return unique_reviews

def read_hash_ids_from_csv(file_path):
    df = pd.read_csv(file_path, encoding='utf-8')
    return df['hash_id'].tolist()

async def main(file_path, years, max_pages):
    hash_ids = read_hash_ids_from_csv(file_path)
    all_reviews = await crawl_reviews_for_all_hash_ids(hash_ids, years, max_pages)

    with open('review_test.csv', 'w', newline='', encoding='utf-8') as f:
        fieldnames = ['user_id', 'user_info', 'hash_id', 'review_date', 'product_id', 'product_brand', 'product_name', 'product_option', 'review_text', 'star_rating', 'helpful_count', 'nicestyle_count', '사이즈', '밝기', '색감', '두께감']
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(all_reviews)

    print(f"크롤링 완료! 총 {len(all_reviews)}개의 리뷰를 저장했습니다.")
#################################################
# CSV 파일 경로와 실행 설정
csv_file_path = 'data.csv'  # hash_id가 포함된 CSV 파일 경로를 여기에 입력하세요
asyncio.run(main(csv_file_path, years, max_pages))
##################################################
# Out:
# 2023 크롤링 진행 상황: 100%|██████████| 28/28 [00:03<00:00,  8.14it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 15/15 [00:01<00:00,  8.15it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 1/1 [00:00<00:00,  1.56it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 23/23 [00:02<00:00,  9.81it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 22/22 [00:02<00:00,  8.87it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 19/19 [00:02<00:00,  8.92it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 15/15 [00:01<00:00,  8.27it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 23/23 [00:02<00:00,  8.40it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 2/2 [00:00<00:00,  4.40it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 24/24 [00:02<00:00,  9.27it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 23/23 [00:02<00:00, 10.33it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 15/15 [00:01<00:00,  9.80it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 41/41 [00:04<00:00, 10.23it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 10/10 [00:01<00:00,  7.04it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 14/14 [00:01<00:00,  9.47it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 23/23 [00:02<00:00, 10.23it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 20/20 [00:02<00:00,  9.39it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 18/18 [00:01<00:00,  9.15it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 22/22 [00:02<00:00,  8.55it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 15/15 [00:01<00:00,  8.56it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 21/21 [00:02<00:00,  9.88it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 21/21 [00:02<00:00,  9.82it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 40/40 [00:03<00:00, 10.39it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 11/11 [00:01<00:00,  8.37it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 24/24 [00:02<00:00,  9.22it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 18/18 [00:02<00:00,  8.76it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 13/13 [00:01<00:00,  7.69it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 18/18 [00:02<00:00,  8.42it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 24/24 [00:02<00:00,  9.82it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 37/37 [00:03<00:00, 10.03it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 10/10 [00:01<00:00,  6.65it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 16/16 [00:01<00:00,  8.61it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 17/17 [00:02<00:00,  7.85it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 1/1 [00:00<00:00,  1.57it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 23/23 [00:02<00:00, 10.50it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 23/23 [00:02<00:00,  8.40it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 11/11 [00:01<00:00,  7.90it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 25/25 [00:03<00:00,  8.11it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 25/25 [00:02<00:00,  9.65it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 16/16 [00:01<00:00,  8.81it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 22/22 [00:02<00:00,  9.09it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 27/27 [00:02<00:00, 10.02it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 14/14 [00:01<00:00,  8.97it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 11/11 [00:01<00:00,  7.22it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 19/19 [00:02<00:00,  8.28it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 21/21 [00:02<00:00,  8.02it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 16/16 [00:01<00:00,  8.43it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 19/19 [00:02<00:00,  9.03it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 15/15 [00:02<00:00,  6.85it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 8/8 [00:02<00:00,  3.62it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 22/22 [00:02<00:00,  9.06it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 17/17 [00:02<00:00,  8.10it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 17/17 [00:02<00:00,  7.74it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 1/1 [00:00<00:00,  1.74it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 24/24 [00:02<00:00,  9.36it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 29/29 [00:03<00:00,  8.95it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 17/17 [00:01<00:00,  8.69it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 1/1 [00:00<00:00,  1.60it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 22/22 [00:02<00:00,  8.33it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 1/1 [00:00<00:00,  1.63it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 25/25 [00:02<00:00,  9.84it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 18/18 [00:01<00:00,  9.49it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 15/15 [00:01<00:00,  9.18it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 20/20 [00:02<00:00,  8.81it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 11/11 [00:01<00:00,  8.58it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 17/17 [00:02<00:00,  7.97it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 16/16 [00:02<00:00,  7.29it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 22/22 [00:03<00:00,  5.83it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 15/15 [00:02<00:00,  5.38it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 9/9 [00:01<00:00,  7.71it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 18/18 [00:02<00:00,  8.24it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 21/21 [00:02<00:00,  9.03it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 12/12 [00:01<00:00,  8.03it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 15/15 [00:01<00:00,  9.41it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 15/15 [00:02<00:00,  7.41it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 8/8 [00:01<00:00,  6.15it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 19/19 [00:02<00:00,  7.43it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 10/10 [00:01<00:00,  6.98it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 19/19 [00:02<00:00,  9.07it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 29/29 [00:03<00:00,  8.09it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 15/15 [00:01<00:00,  9.53it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 24/24 [00:02<00:00,  9.90it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 14/14 [00:01<00:00,  7.42it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 25/25 [00:02<00:00, 10.42it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 10/10 [00:01<00:00,  6.23it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 71/71 [00:06<00:00, 11.55it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 20/20 [00:02<00:00,  8.51it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 27/27 [00:02<00:00,  9.33it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 13/13 [00:01<00:00,  7.38it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 26/26 [00:02<00:00,  9.78it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 10/10 [00:01<00:00,  6.24it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 1/1 [00:00<00:00,  1.04it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 21/21 [00:02<00:00,  8.05it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 17/17 [00:01<00:00,  8.61it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 15/15 [00:01<00:00,  8.63it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 12/12 [00:01<00:00,  7.76it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 19/19 [00:02<00:00,  8.62it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 38/38 [00:03<00:00, 10.36it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 8/8 [00:01<00:00,  5.13it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 1/1 [00:00<00:00,  1.09it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 21/21 [00:02<00:00,  8.92it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 26/26 [00:02<00:00,  9.61it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 14/14 [00:01<00:00,  7.22it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 30/30 [00:03<00:00,  9.02it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 11/11 [00:01<00:00,  7.48it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 23/23 [00:02<00:00,  8.88it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 14/14 [00:01<00:00,  7.68it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 21/21 [00:02<00:00,  9.90it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 10/10 [00:01<00:00,  7.14it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 26/26 [00:02<00:00,  9.65it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 16/16 [00:02<00:00,  7.20it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 19/19 [00:02<00:00,  8.59it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 11/11 [00:01<00:00,  7.15it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 24/24 [00:02<00:00,  8.47it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 12/12 [00:01<00:00,  7.64it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 20/20 [00:02<00:00,  8.50it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 17/17 [00:02<00:00,  8.36it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 4/4 [00:00<00:00,  4.78it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 20/20 [00:02<00:00,  8.07it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 7/7 [00:01<00:00,  6.11it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 17/17 [00:02<00:00,  8.06it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 20/20 [00:02<00:00,  8.07it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 12/12 [00:01<00:00,  6.95it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 12/12 [00:01<00:00,  8.37it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 17/17 [00:02<00:00,  7.99it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 19/19 [00:02<00:00,  9.13it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 16/16 [00:02<00:00,  7.21it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 26/26 [00:02<00:00, 10.15it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 9/9 [00:01<00:00,  6.90it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 22/22 [00:02<00:00,  8.31it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 12/12 [00:01<00:00,  8.73it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 16/16 [00:01<00:00,  8.46it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 16/16 [00:02<00:00,  7.56it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 23/23 [00:02<00:00,  9.04it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 11/11 [00:01<00:00,  7.16it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 22/22 [00:02<00:00,  8.69it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 13/13 [00:01<00:00,  8.07it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 4/4 [00:00<00:00,  6.04it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 21/21 [00:02<00:00,  9.05it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 24/24 [00:02<00:00,  9.75it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 10/10 [00:01<00:00,  7.07it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 7/7 [00:01<00:00,  5.27it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 17/17 [00:02<00:00,  7.76it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 22/22 [00:02<00:00,  9.34it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 9/9 [00:01<00:00,  5.50it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 31/31 [00:03<00:00,  9.00it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 10/10 [00:01<00:00,  8.03it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 19/19 [00:02<00:00,  8.53it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 13/13 [00:01<00:00,  8.37it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 17/17 [00:01<00:00,  8.76it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 16/16 [00:02<00:00,  7.24it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 39/39 [00:03<00:00, 10.44it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 8/8 [00:02<00:00,  3.55it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 20/20 [00:03<00:00,  5.78it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 14/14 [00:02<00:00,  6.43it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 21/21 [00:02<00:00,  7.79it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 16/16 [00:01<00:00,  8.83it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 34/34 [00:03<00:00,  9.98it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 9/9 [00:01<00:00,  7.86it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 16/16 [00:02<00:00,  7.71it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 16/16 [00:01<00:00,  8.39it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 21/21 [00:02<00:00,  8.22it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 13/13 [00:01<00:00,  7.59it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 20/20 [00:02<00:00,  9.81it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 12/12 [00:01<00:00,  6.35it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 22/22 [00:02<00:00,  9.03it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 9/9 [00:01<00:00,  8.50it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 18/18 [00:02<00:00,  8.34it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 14/14 [00:01<00:00,  7.49it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 13/13 [00:01<00:00,  6.61it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 19/19 [00:02<00:00,  9.38it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 23/23 [00:02<00:00,  9.19it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 11/11 [00:01<00:00,  6.50it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 21/21 [00:02<00:00,  9.00it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 13/13 [00:01<00:00,  9.71it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 14/14 [00:01<00:00,  9.10it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 17/17 [00:02<00:00,  7.66it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 19/19 [00:01<00:00,  9.51it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 17/17 [00:02<00:00,  7.74it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 3/3 [00:01<00:00,  2.25it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 22/22 [00:02<00:00,  9.04it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 18/18 [00:02<00:00,  7.69it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 13/13 [00:01<00:00,  8.46it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 32/32 [00:03<00:00,  9.81it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 9/9 [00:01<00:00,  5.72it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 29/29 [00:02<00:00,  9.85it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 11/11 [00:01<00:00,  7.22it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 38/38 [00:03<00:00,  9.95it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 1/1 [00:00<00:00,  1.46it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 22/22 [00:02<00:00,  7.93it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 13/13 [00:01<00:00,  7.53it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 15/15 [00:02<00:00,  6.83it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 15/15 [00:01<00:00,  8.15it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 22/22 [00:02<00:00,  9.29it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 14/14 [00:01<00:00,  8.99it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 22/22 [00:02<00:00,  9.00it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 12/12 [00:01<00:00,  8.28it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 23/23 [00:02<00:00,  9.11it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 11/11 [00:01<00:00,  9.04it/s]
# 2023 크롤링 진행 상황: 100%|██████████| 2/2 [00:00<00:00,  2.68it/s]
# 2024 크롤링 진행 상황: 100%|██████████| 18/18 [00:02<00:00,  7.63it/s]
# 크롤링 완료! 총 38905개의 리뷰를 저장했습니다.
